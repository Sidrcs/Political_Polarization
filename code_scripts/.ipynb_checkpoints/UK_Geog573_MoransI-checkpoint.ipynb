# %%
# !pip install geopandas
# !pip instal pysal
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting geopandas
#   Downloading geopandas-0.12.2-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 19.3 MB/s eta 0:00:00
# Collecting pyproj>=2.6.1.post1
#   Downloading pyproj-3.5.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 36.1 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from geopandas) (23.1)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from geopandas) (1.5.3)
# Requirement already satisfied: shapely>=1.7 in /usr/local/lib/python3.9/dist-packages (from geopandas) (2.0.1)
# Collecting fiona>=1.8
#   Downloading Fiona-1.9.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.1/16.1 MB 43.5 MB/s eta 0:00:00
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.9/dist-packages (from fiona>=1.8->geopandas) (8.1.3)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.9/dist-packages (from fiona>=1.8->geopandas) (23.1.0)
# Collecting munch>=2.3.2
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.9/dist-packages (from fiona>=1.8->geopandas) (6.4.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.9/dist-packages (from fiona>=1.8->geopandas) (2022.12.7)
# Collecting click-plugins>=1.0
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0.0->geopandas) (2.8.2)
# Requirement already satisfied: numpy>=1.20.3 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0.0->geopandas) (1.22.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0.0->geopandas) (2022.7.1)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from munch>=2.3.2->fiona>=1.8->geopandas) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata->fiona>=1.8->geopandas) (3.15.0)
# Installing collected packages: pyproj, munch, cligj, click-plugins, fiona, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.7.2 fiona-1.9.3 geopandas-0.12.2 munch-2.5.0 pyproj-3.5.0
# ERROR: unknown command "instal" - maybe you meant "install"

# %%
# !pip install libpysal
# !pip install esda
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting libpysal
#   Downloading libpysal-4.7.0-py3-none-any.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 50.1 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=0.11 in /usr/local/lib/python3.9/dist-packages (from libpysal) (1.10.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from libpysal) (2.27.1)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.9/dist-packages (from libpysal) (3.2.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from libpysal) (3.1.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from libpysal) (1.5.3)
# Requirement already satisfied: numpy>=1.3 in /usr/local/lib/python3.9/dist-packages (from libpysal) (1.22.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from libpysal) (4.11.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from libpysal) (23.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->libpysal) (2.4.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->libpysal) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->libpysal) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->libpysal) (2022.7.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->libpysal) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->libpysal) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->libpysal) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->libpysal) (2022.12.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->libpysal) (1.16.0)
# Installing collected packages: libpysal
# Successfully installed libpysal-4.7.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting esda
#   Downloading esda-2.4.3.tar.gz (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.6/116.6 kB 11.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scipy>=0.11 in /usr/local/lib/python3.9/dist-packages (from esda) (1.10.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from esda) (1.5.3)
# Requirement already satisfied: libpysal in /usr/local/lib/python3.9/dist-packages (from esda) (4.7.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from esda) (1.2.2)
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in /usr/local/lib/python3.9/dist-packages (from scipy>=0.11->esda) (1.22.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from libpysal->esda) (23.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from libpysal->esda) (2.27.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from libpysal->esda) (3.1.2)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.9/dist-packages (from libpysal->esda) (3.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from libpysal->esda) (4.11.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->esda) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->esda) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->esda) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->esda) (1.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->esda) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->libpysal->esda) (2.4.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->libpysal->esda) (2.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->libpysal->esda) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->libpysal->esda) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->libpysal->esda) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->libpysal->esda) (2.0.12)
# Building wheels for collected packages: esda
#   Building wheel for esda (setup.py) ... done
#   Created wheel for esda: filename=esda-2.4.3-py3-none-any.whl size=122782 sha256=8aab9d888ecfbb8fa2d67282ac38a11d9999173d778fae09ad5b9a4bbb342bee
#   Stored in directory: /root/.cache/pip/wheels/92/4b/14/df69615cd54ad1ce64b70d141dee8b269ebc7ace679cef9f3f
# Successfully built esda
# Installing collected packages: esda
# Successfully installed esda-2.4.3

# %%
import geopandas as gpd
uk_gdf = gpd.read_file("/content/UK_regions.geojson")
uk_gdf.plot()


uk_gdf = uk_gdf.rename(columns = {"nuts118nm" : "region_name"})
uk_gdf.head()
# Out:
#   nuts118cd         region_name adm1_code                name  \
# 0       UKC          North East      UK-0          North East
# 1       UKD          North West      UK-1          North West
# 2       UKE  Yorkshire & Humber      UK-2  Yorkshire & Humber
# 3       UKF       East Midlands      UK-3       East Midlands
# 4       UKG       West Midlands      UK-4       West Midlands
#
#                                             geometry
# 0  MULTIPOLYGON (((-0.79335 54.55831, -0.89818 54...
# 1  POLYGON ((-2.17021 54.45820, -2.15900 54.47203...
# 2  POLYGON ((0.01683 53.52586, -0.06185 53.58254,...
# 3  POLYGON ((0.01683 53.52586, -0.06505 53.51874,...
# 4  POLYGON ((-1.33190 52.16849, -1.31313 52.19047...

# %%
import pandas as pd
output_df_1995 = pd.read_csv("/content/polarization1995_data.csv")
output_df_1995 = output_df_1995.rename(columns = {"county" : "region_name"})

output_df_2000 = pd.read_csv("/content/polarization2000_data.csv")
output_df_2000 = output_df_2000.rename(columns = {"county" : "region_name"})

output_df_2004 = pd.read_csv("/content/polarization2004_data.csv")
output_df_2004 = output_df_2004.rename(columns = {"county" : "region_name"})

output_df_1995.head()
# Out:
#    Unnamed: 0  std_dev_age  native_share  education_variability  \
# 0           0    18.929772      0.946183                  399.0
# 1           1    18.511457      0.953883                  411.5
# 2           2    17.650852      0.938341                  445.5
# 3           3    18.640090      0.964623                  211.5
# 4           4    18.636682      0.955357                  559.5
#
#        region_name  job_variability  frac_employed  median_income  gini_index  \
# 0    East Midlands            399.0       0.446809    6427.445312    0.485968
# 1  East of England            411.5       0.470874    7721.132812    0.497099
# 2           London            445.5       0.487668    8279.160645    0.520353
# 3       North East            211.5       0.464623    6390.706543    0.455352
# 4       North West            559.5       0.468750    6927.100586    0.496123
#
#    Lindqvist_Ostling_S1  Abramowitz_Saunders_S1  Duca_Saving_S1  \
# 0              6.068943                3.198999        0.003276
# 1              5.260862                3.135922        0.001974
# 2              6.656564                3.339686        0.000011
# 3              5.040434                3.216981        0.000064
# 4              5.844236                3.283929        0.000887
#
#    Lindqvist_Ostling_S2  Abramowitz_Saunders_S2  Duca_Saving_S2  \
# 0              5.688696                2.892365        0.001800
# 1              5.220032                2.969660        0.001221
# 2              5.990008                2.882287        0.002245
# 3              4.642441                2.875000        0.000064
# 4              5.414720                2.801786        0.000036
#
#    Lindqvist_Ostling_S3  Abramowitz_Saunders_S3  Duca_Saving_S3
# 0              5.603750                2.986233        0.000210
# 1              5.111845                3.072816        0.000129
# 2              6.093646                3.086323        0.000412
# 3              4.252905                2.771226        0.000062
# 4              4.888318                2.836607        0.000392

# %%
merged_df_1995 = pd.merge(output_df_1995, uk_gdf[["region_name","adm1_code", "geometry"]], on = "region_name")
merged_df_1995 = merged_df_1995.drop(columns = ["Unnamed: 0"], axis = 1)

merged_gdf_1995 = gpd.GeoDataFrame(merged_df_1995, geometry = "geometry")

merged_df_2000 = pd.merge(output_df_2000, uk_gdf[["region_name","adm1_code", "geometry"]], on = "region_name")
merged_df_2000 = merged_df_2000.drop(columns = ["Unnamed: 0"], axis = 1)

merged_gdf_2000 = gpd.GeoDataFrame(merged_df_2000, geometry = "geometry")

merged_df_2004 = pd.merge(output_df_2004, uk_gdf[["region_name","adm1_code", "geometry"]], on = "region_name")
merged_df_2004 = merged_df_2004.drop(columns = ["Unnamed: 0"], axis = 1)

merged_gdf_2004 = gpd.GeoDataFrame(merged_df_2004, geometry = "geometry")

# %%
import libpysal as lps
import esda
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
y = merged_gdf_2000["Abramowitz_Saunders_S3"] # target variable
wq =  lps.weights.Queen.from_dataframe(merged_gdf_2000) # compute the spatial weights
wq.transform = 'r' # spatial weights require that the matrix is row-standardized 
np.random.seed(12345)
mi = esda.moran.Moran(y, wq)
mi.I
# Out:
# 0.5473015641920729

# %%
li = esda.moran.Moran_Local(y, wq)

# %%
sig = 1 * (li.p_sim < 0.05)
hotspot = 1 * (sig * li.q==1)
coldspot = 3 * (sig * li.q==3)
doughnut = 2 * (sig * li.q==2)
diamond = 4 * (sig * li.q==4)
spots = hotspot + coldspot + doughnut + diamond
spots
# Out:
# array([0, 1, 1, 3, 3, 3, 1, 0, 0, 0, 0])

# %%
spot_labels = [ '0 ns', '1 hot spot', '2 doughnut', '3 cold spot', '4 diamond']
labels = [spot_labels[i] for i in spots]

# %%
df = merged_gdf_2000
from matplotlib import colors
hmap = colors.ListedColormap(['#ccc','#a63603','#fe9929','#feedde','#993404'])
f, ax = plt.subplots(1, figsize=(9, 9))
df.assign(cl=labels).plot(column='cl', categorical=True, \
        k=2, cmap=hmap, linewidth=0.1, ax=ax, \
        edgecolor='white', legend=True, legend_kwds={'loc': 'center left', 'bbox_to_anchor':(1,0.5)})
ax.set_axis_off()
plt.title(f"Polarization 2000 for Statement 3")
plt.show()

# %%
import matplotlib.pyplot as plt

# create one row, multiple columns of sub-figures
fig, ax = plt.subplots(1, 3, figsize=(15, 8)) 
# adjust horizontal space between subplots
fig.subplots_adjust(wspace=0.1) 

# creating various plots using statement S3: It is the government’s responsibility to provide a job for everyone who wants one.

merged_gdf_1995.plot(ax=ax[0], column='job_variability', cmap='Reds', legend=True, \
                     legend_kwds={'label': "job_variability", 'orientation': "horizontal"})
merged_gdf_2000.plot(ax=ax[1],  column='job_variability', cmap='Reds', legend=True, \
                     legend_kwds={'label': "job_variability",'orientation': "horizontal"})
merged_gdf_2004.plot(ax=ax[2],  column='job_variability', cmap='Reds', legend=True, \
         legend_kwds={'label': "job_variability", 'orientation': "horizontal"})

plt.suptitle("job variability change in 1995 - 2000 - 2004 based on Statement 3")
plt.show()
